# %%
import numpy as np
import os
import pandas as pd

# %%
os.chdir("../Prepros_training_data")

# %%
retval = os.getcwd()
print("Current working directory %s" % retval)
df_controlls = pd.read_csv('inputs.csv', header=None)
df_controlls
# Out:
# Current working directory C:\Users\hanso\Desktop\MariPlayer\Prepros_training_data
#        0      1      2      3      4      5      6      7      8
# 0    NaN      0      1      2      3      4      5      6      7
# 1    0.0  False  False  False  False  False  False  False  False
# 2    1.0  False  False  False  False  False  False  False  False
# 3    2.0  False  False  False  False  False  False  False  False
# 4    3.0  False  False  False  False  False  False  False  False
# 5    4.0  False  False  False  False  False  False  False  False
# 6    5.0  False  False  False  False  False  False  False  False
# 7    6.0  False  False  False  False  False  False  False  False
# 8    7.0  False  False  False  False  False  False  False  False
# 9    8.0  False  False  False  False  False  False  False  False
# 10   9.0   True  False   True  False  False  False  False  False
# 11  10.0  False  False   True  False  False  False  False  False
# ...

# %%
intervall = []
nr_rows = len(df_controlls)
for i in range(nr_rows-20, nr_rows):
    intervall.append(i)
intervall
# Out:
# [68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87]

# %%
df_controlls_deleted = df_controlls.drop(intervall)
df_controlls_deleted.to_csv('inputs.csv')

# %% [markdown]
# ## Cut inputs

# %%
df_controlls_deleted
# Out:
#        0      1      2      3      4      5      6      7      8
# 0    NaN      0      1      2      3      4      5      6      7
# 1    0.0  False  False  False  False  False  False  False  False
# 2    1.0  False  False  False  False  False  False  False  False
# 3    2.0  False  False  False  False  False  False  False  False
# 4    3.0  False  False  False  False  False  False  False  False
# 5    4.0  False  False  False  False  False  False  False  False
# 6    5.0  False  False  False  False  False  False  False  False
# 7    6.0  False  False  False  False  False  False  False  False
# 8    7.0  False  False  False  False  False  False  False  False
# 9    8.0  False  False  False  False  False  False  False  False
# 10   9.0   True  False   True  False  False  False  False  False
# 11  10.0  False  False   True  False  False  False  False  False
# 12  11.0  False  False   True  False  False  False  False  False
# ...

# %% [markdown]
# ## Cut images
